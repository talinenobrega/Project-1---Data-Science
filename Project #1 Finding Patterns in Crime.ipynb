# %% [markdown]
# ## <center>Universidade Federal do Rio Grande do Norte<br>Programa de Pós-Graduação em Engenharia Elétrica e Computação<br>Module: Data Science (Tópicos Especiais F)<br>Professor Ivanovitch Silva
#
# ### <center> Students: Marianne Diniz / Taline Nóbrega

# %% [markdown]
# # <center>Project 1: Finding Patterns in Crime

# %% [markdown]
# ## 1. Introduction
#
# This is a project regarding crime data from Montgomery County, MD. The data was assembled by a respected law enforcement records-management system called "EJustice", which is used by the Montgomery County Police Department and it can be download from [Police Foundation](https://data.policefoundation.org). The crimes were classified according to Maryland criminal code. <br>
# In order to protect victims information, all personal data was removed or modified.

# %% [markdown]
# ## 2. The data
#
#
# The data is composed of 23369 rows and 22 columns from a database collected in 2013. Each row represents a crime reported by a law enforcement officer and each column presents information about the incident.
#
# <br><br>
# As an initial analysis, the first five rows can be displayed to get a better idea of the data structure
#
# >```python
# import pandas as pd
# crimes = pd.read_csv("MontgomeryCountyCrime2013.csv") # Reading the data
# crimes.head() # Displaying the first 5 rows
# ```
#
# |#| Incident ID | CR Number | Dispatch Date / Time | Class                  | Class Description | Police District Name                | Block Address      | City               | State         | Zip Code | ...     | Sector | Beat | PRA | Start Date / Time | End Date / Time        | Latitude | Longitude | Police District Number | Location | Address Number |         |
# |-------------|-----------|----------------------|------------------------|-------------------|-------------------------------------|--------------------|--------------------|---------------|----------|---------|--------|------|-----|-------------------|------------------------|----------|-----------|------------------------|----------|----------------|---------|
# | 0           | 200939101 | 13047006             | 10/02/2013 07:52:41 PM | 511               | BURG FORCE-RES/NIGHT                | OTHER              | 25700 MT RADNOR DR | DAMASCUS      | MD       | 20872.0 | ...    | NaN  | NaN | NaN               | 10/02/2013 07:52:00 PM | NaN      | NaN       | NaN                    | OTHER    | NaN            | 25700.0 |
# | 1           | 200952042 | 13062965             | 12/31/2013 09:46:58 PM | 1834              | CDS-POSS MARIJUANA/HASHISH          | GERMANTOWN         | GUNNERS BRANCH RD  | GERMANTOWN    | MD       | 20874.0 | ...    | M    | 5M1 | 470.0             | 12/31/2013 09:46:00 PM | NaN      | NaN       | NaN                    | 5D       | NaN            | NaN     |
# | 2           | 200926636 | 13031483             | 07/06/2013 09:06:24 AM | 1412              | VANDALISM-MOTOR VEHICLE             | MONTGOMERY VILLAGE | OLDE TOWNE AVE     | GAITHERSBURG  | MD       | 20877.0 | ...    | P    | 6P3 | 431.0             | 07/06/2013 09:06:00 AM | NaN      | NaN       | NaN                    | 6D       | NaN            | NaN     |
# | 3           | 200929538 | 13035288             | 07/28/2013 09:13:15 PM | 2752              | FUGITIVE FROM JUSTICE(OUT OF STATE) | BETHESDA           | BEACH DR           | CHEVY CHASE   | MD       | 20815.0 | ...    | D    | 2D1 | 11.0              | 07/28/2013 09:13:00 PM | NaN      | NaN       | NaN                    | 2D       | NaN            | NaN     |
# | 4           | 200930689 | 13036876             | 08/06/2013 05:16:17 PM | 2812              | DRIVING UNDER THE INFLUENCE         | BETHESDA           | BEACH DR           | SILVER SPRING | MD       | 20815.0 | ...    | D    | 2D3 | 178.0             | 08/06/2013 05:16:00 PM | NaN      | NaN       | NaN                    | 2D       | NaN            | NaN     |
#
#
# <br><br>
#
# The output table did not show all columns names. So, in order to access this information, the following code can be run.
#
# >```python
# crimes.columns # Displaying the columns name
# ```
#
# >```python
# Output:Index(['Incident ID', 'CR Number', 'Dispatch Date / Time', 'Class',
#        'Class Description', 'Police District Name', 'Block Address', 'City',
#        'State', 'Zip Code', 'Agency', 'Place', 'Sector', 'Beat', 'PRA',
#        'Start Date / Time', 'End Date / Time', 'Latitude', 'Longitude',
#        'Police District Number', 'Location', 'Address Number'],
#       dtype='object')
# ```
#
# Each column has a specific meaning and it contributes to provide more information about the incident. For example, the column **Police district number** indicates the major Police Boundary. This column can present values varying from 1D to 6D, including the option OTHER. In other words, it indicates in which District of Montgomery County the incident occurred.
#
# - **1D: **1st District - Rockville
# - **2D: **2nd District – Bethesda
# - **3D: **3rd District – Silver Spring
# - **4D: **4th District – Wheaton
# - **5D: **5th District – Germantown
# - **6D: **6th District – Montgomery Village
# - **OTHER: **Other District
#
#
# All columns were investigated and their specific description is presented in the following table.
# <br>
# <br>
#
# |**COLUMN**               |**DATA TYPE**      |**DESCRIPTION**                                                       |
# |-------------------------|-------------------|----------------------------------------------------------------------|
# |Incident ID              |number             |Number that identifies an incident                                    |
# |CR Number                |number             |Police Report Number. Tracking number assigned to an incident. Report the investigation|
# |Dispatch date/time       |floating timestamp |The actual date and time an Officer was dispatched in order to verify the incident|
# |Class                    |floating timestamp |The actual date and time an Officer was dispatched in order to verify the incident
# |Class description        |text               |Common name description of the incident class type                    |
# |District name            |text               |Name of District, i.e. Rockville                                      |
# |Block Address            |text               |Address in 100 block level                                            |
# |City                     |text               |City where the crime occured                                          |
# |State                    |text               |State where the crime occured                                         |
# |Zip Code                 |number, float      |Postal code number                                                    |
# |Agency                   |text               |Assigned Police Department                                            |
# |Place                    |text               |Description of the place where the crime occured                      |
# |Sector                   |text               |Police sector name. It is a subset of District                        |
# |Beat                     |text               |Police patrol area. It is a subset of Sector                          |
# |PRA                      |text               |Police Response Area. It is a subset of Beat                          |
# |Start date/time          |floating timestamps|Indicates when the incident started. Occurred from date/time          |
# |End data/time            |floating timestamps|Indicates when the incident started. Occurred from date/time          |
# |Latitude                 |number             |Latitude                                                              |
# |Longitude                |number             |Longitude                                                             |
# |Police district number   |text               |Indicates the major Police Boundary                                   |
# |Location                 |geolocation        |Array with 3 elements in it: latitude, longitude and. A JSON object containing the U.S. address|
# |Number address           |number, float      |                                                                      |
#
#
#
# During investigation was possible to verify that some columns have missing values. This fact may be a problem depending on the analyses that are being taken. For example, if a column has missing value and the interest is to measure the mean, the function may not consider the missing values and probably the result will not be consistent.
# Therefore, it is important to certify which columns have NaN (Not a Number) values before proceeding with data analysis. The following code returns how many NaN there are in which column of the data.
#
# >```python
# crimes.apply(lambda x: sum(x.isnull()),axis=0)
# ```
# <br>
# >```python
# Incident ID                   0
# CR Number                     0
# Dispatch Date / Time          0
# Class                         0
# Class Description             0
# Police District Name          0
# Block Address                 0
# City                          0
# State                         0
# Zip Code                     30
# Agency                        0
# Place                         0
# Sector                       46
# Beat                          8
# PRA                           6
# Start Date / Time             0
# End Date / Time           10178
# Latitude                    161
# Longitude                   161
# Police District Number        0
# Location                    161
# Address Number              132
# dtype: int64
# ```

# %% [markdown]
# ## 3. Analyzing the times of crimes
#
#
# The column **Dispatch Date / Time** provides information regarding the actual date and time an Officer was dispatched to verify an incident. This data is useful to figure out when crimes are most likely to occur.
#
# The function [pandas.to_datetime](http://pandas.pydata.org/pandas-docs/stable/generated/pandas.to_datetime.html) can be used to extract this information from the data. The following statement returns how many incidents occurred in which weekday.
#
# >```python
# d_time = pd.to_datetime(crimes["Dispatch Date / Time"]).dt.weekday_name.value_counts()
# print (d_time)
# ```
#
# >```python
# Tuesday      3836
# Monday       3734
# Wednesday    3611
# Friday       3594
# Thursday     3404
# Saturday     2807
# Sunday       2383
# Name: Dispatch Date / Time, dtype: int64
# ```
#
# And following the same idea, it is possible to analyze in which month an Officer was dispatched more frequently.
#
# >```python
# d_time = pd.to_datetime(crimes["Dispatch Date / Time"]).dt.month.value_counts()
# print (d_time)
# ```
#
# >```python
# 10    4075
# 8     4002
# 11    3941
# 9     3927
# 12    3904
# 7     3520
# Name: Dispatch Date / Time, dtype: int64
# ```
#
#
# **Dispatch Date / Time** column can also provide information about what time of day the most crimes are committed
#
# >```python
# d_time2 = pd.to_datetime(crimes["Dispatch Date / Time"]).dt.hour
# d_time = list (d_time2)
# night = 0
# morning = 0
# afternoon = 0
# evening = 0
# for i in d_time :
#     if (i>=0 and i <6):
#            night += 1
#     elif (i>=6 and i<12):
#            morning += 1
#     elif (i>=12 and i<18):
#            afternoon += 1
#     else:
#            evening += 1
# print ("Night", night)
# print ("Morning:", morning)
# print ("Afternoon:", afternoon)
# print ("Evening:", evening)
# ```
#
#
# >```python
# Night 3269
# Morning: 6971
# Afternoon: 6842
# Evening: 6287
# ```
#
# The functions returned interesting information about the date/time when an Officer was designated to verify an incident. However, it is important to emphasize that these results may not be the same if the analysis takes into account the date/time the crime occurred (correspondent to column **Start date/time**). If the column **Start date/time** is used in those same functions applied previously, the results should be:
#
#
# >```python
# Friday       3719
# Tuesday      3463
# Wednesday    3430
# Thursday     3349
# Saturday     3343
# Monday       3157
# Sunday       2908
# Name: Start Date / Time, dtype: int64
# ```
# >```python
# 10    3993
# 8     3971
# 9     3883
# 11    3846
# 12    3560
# 7     3450
# 6      307
# 5      108
# 1       95
# 4       66
# 3       56
# 2       34
# Name: Start Date / Time, dtype: int64
# ```
# >```python
# Night 4504
# Morning: 4100
# Afternoon: 7133
# Evening: 7632
# ```
#
# Therefore, it is clear that each column provides differents comprehensions about the date/time an incident occurred. According to the results obtained, the day of the week that most crimes were committed was **Tuesday** for **Dispatch Date / Time**.  analysis and **Friday** for **Start date/time**. So, it is possible to make the following assumptions:
#
# - The day of the week that most crimes are committed is Friday (3719 incidents) and in the most cases, an Officer was assigned to verify the situation on Tuesday (3836 incidents). Nevertheless, the second weekday most common for crimes occurrence is Tuesday (3463), which assures some relationship between the information provided by both columns.
#
# - The time of day that most crimes were committed is during the evening. These statement is confirmed by **Start date/time** and **Dispatch Date / Time** columns. Moreover, this similarity between these two columns shows that normally an Officer does not delay to answer a call.
#
# - The month that most crimes are committed is October following by August.
#
#
# In short, if the interest is to analyze when a specific incident occurred, the **Start date/time** column will provide more accurate information than **Dispatch Date / Time**. However, **Dispatch Date / Time** column is more efficient to analyze how these incidents are being treated by the Police department and how efficient they are to attend a call. In addition, this kind of information can be useful to determine when police departments should have more staff working.
#
# Graphs can be contructs to clarify the interpretation made previewsly by importing the **matplotlib.pyplot** and using the results from **Start date/time** column
#
#
# >```python
# import matplotlib.pyplot as plt
# pd.to_datetime(crimes["Start Date / Time"]).dt.month.value_counts().plot(kind='bar', color='orangered')
# plt.title('Crimes Distribution by Month')
# plt.show()
# pd.to_datetime(crimes["Start Date / Time"]).dt.weekday_name.value_counts().plot(kind='bar', color='orangered')
# plt.title('Crimes Distribution by Weekday')
# plt.show()
# ```
#
# <img width="400" src="Crimes distribution by month.png">
# <br><br>
# <img width="400" src="Crimes Distribution by Weekday.png">

# %% [markdown]
# ## 4. Analyzing locations of crimes
#
# There are few columns that encode information about the location of crimes:
#
# - Police District Name
# - Block Address
# - Zip Code
# - Sector
# - Beat
# - Latitude
# - Longitude
# - Police District Number
# - Location
# - Address Number
#
#
# These columns have varying numbers of missing values, and varying granularity. Some of those represent areas with large granularity (like Police Districts), whereas some represent areas with small granularity, like **Latitude**, and **Longitude**.
#
# Considering that:
#
# - **Granularity**: Areas that are too small aren't great, because only a few crimes were committed inside them, which makes it hard to analyze and compare.
# - **Comprehensibility**: the data provided should be easy to understand.
# - **Missing values**: these may compromise the data analysis. So, it is recommended to use a group of data that does not have missing values.
#
#
# The Granularity can be inspected by examining how many distinct factors there are in each column. In other words, this means how many subtypes of information, or details, it is possible to extract from each one.
#
# >```python
# crimes_granularity = ['Police District Name', 'Block Address', 'Zip Code', 'Sector', 'Beat', 'Latitude', 'Longitude', 'Police District Number', 'Location', 'Address Number']
# for i in crimes_granularity :
# g = crimes[i].value_counts().count()
# print (i, g)
# ```
#
# >```python
# Police District Name 8
# Block Address 8143
# Zip Code 49
# Sector 15
# Beat 42
# Latitude 8065
# Longitude 8065
# Police District Number 8
# Location 8065
# Address Number 286
# ```
#
# The column with more details will guarantee more flexibility to obtain answers. However, this characteristic will result in a higher volume of data and, consequently, it will affect the processing speed. This situation defines a low granularity
# Nevertheless, a big granularity is considered when the analysis has small amount of detail, which means a small volume of data and a better data summarization and performance.
#
# From the results obtained in the last algorithm, the column with bigger granularity is **Police District Name** once it presents the lowest variability
# <br>
# The Comprehensibility factor is determined by the clarity in understanding the data. Parameters that depend on prior interpretation may be not simple to understand. For example, it is necessary to have a minimum knowledge about maps orientation to interpret latitude and longitude parameters. Therefore, the columns that provide simple interpretation is **Police District Name** and **Police District Number**
# <br><br>
# In section 2 was discussed about the structure of the data. In that section was presented how many NaN values each column of the data presents. This information is crucial to determiny which column is more apropriate based on the criteria **Mission value**. According to the results presented on that section, the columns related to location that do not have missing value are: **Police District Name**, **Block Address** and **Police District Number**
#
# Thus, these criteria allow us to verify that the best columns to analyze location are:
#
# - **Granularity criteria: **Police District Name
# - **Comprehensibility criteria: **Police District Name and Police District Number
# - **Missing values: **Police District Name, Block Address and Police District Number
#
#
# Therefore, the chosen column to proceed with the analysis was **Police District Name**, once it satisfies the criteria discussed above.
#
# <br>
# The first analysis is to verify in what area did the most crimes occur. The following code returns how many times each Police District Name appeared in the data.
#
# >```python
# crimes["Police District Name"].value_counts()
# ```
#
# >```python
# SILVER SPRING         5533
# WHEATON               4375
# MONTGOMERY VILLAGE    3812
# ROCKVILLE             3480
# BETHESDA              3383
# GERMANTOWN            2755
# TAKOMA PARK             23
# OTHER                    8
# ```
#
# And to verify in what physical locations does these areas correspond to, we just need to combine the obtained results in the last analysis with the column **City**
#
#
# >```python
# crimes.groupby(["Police District Name"])['City'].value_counts()
# ```
#
# >```python
# BETHESDA              BETHESDA              1736
#                       ROCKVILLE              534
#                       CHEVY CHASE            496
#                       KENSINGTON             275
#                       POTOMAC                162
#                       SILVER SPRING          158
#                       CABIN JOHN              18
#                       GLEN ECHO                4
# GERMANTOWN            GERMANTOWN            2128
#                       DAMASCUS               229
#                       CLARKSBURG             173
#                       GAITHERSBURG           119
#                       BOYDS                   86
#                       DICKERSON                7
#                       BARNESVILLE              4
#                       MOUNT AIRY               3
#                       BROOKEVILLE              2
#                       DERWOOD                  2
#                       MONTGOMERY VILLAGE       1
#                       POOLESVILLE              1
# MONTGOMERY VILLAGE    GAITHERSBURG          2883
#                       MONTGOMERY VILLAGE     686
#                       ROCKVILLE              115
#                       DERWOOD                114
#                       WASHINGTON GROVE         6
#                       GERMANTOWN               4
#                       OLNEY                    4
# OTHER                 CHEVY CHASE              1
#                       DAMASCUS                 1
#                       GAITHERSBURG             1
#                                             ...
#                       LAUREL                   1
#                       OLNEY                    1
# ROCKVILLE             ROCKVILLE             2394
#                       GAITHERSBURG           398
#                       POTOMAC                365
#                       DERWOOD                154
#                       POOLESVILLE            104
#                       GERMANTOWN              37
#                       DICKERSON               19
#                       BOYDS                    4
#                       SILVER SPRING            3
#                       BEALLSVILLE              2
# SILVER SPRING         SILVER SPRING         5102
#                       BURTONSVILLE           304
#                       TAKOMA PARK            122
#                       SPENCERVILLE             3
#                       CHEVY CHASE              1
#                       LAUREL                   1
# TAKOMA PARK           TAKOMA PARK             19
#                       SILVER SPRING            4
# WHEATON               SILVER SPRING         3359
#                       ROCKVILLE              410
#                       OLNEY                  375
#                       KENSINGTON              88
#                       BROOKEVILLE             68
#                       SANDY SPRING            43
#                       ASHTON                  19
#                       SPENCERVILLE             6
#                       BRINKLOW                 5
#                       GAITHERSBURG             2
# ```
#
# This output presents the cities of each Police District and the amount of incidents registered in each one. Another interesting interpretation is to verify the most common crimes commited in each Police District.
# The following code combines two columns (Police District Name and Class Description) and set this group of columns in relation to the column Class.
#
# >```python
# c = crimes.pivot_table(index=['Police District Name','Class Description'], values="Class", aggfunc='count')
# c.reset_index().sort_values(['Police District Name','Class'],ascending=[True, False]).groupby(['Police District Name']).head(3).set_index(['Police District Name','Class Description'])
# ```
#
#
# | **Police District Name** | **Class Description**          |**Class**|
# |-------------------|-------------------------------|-----|
# |**BETHESDA**           |DRIVING UNDER THE INFLUENCE    |263 |
# |                   |LARCENY FROM BUILDING OVER 200 |215 |
# |                   |LARCENY FROM AUTO OVER 200     |186 |
# |**GERMANTOWN**         |DRIVING UNDER THE INFLUENCE    |252 |
# |                   |CDS-POSS MARIJUANA/HASHISH     |246 |
# |                   |POL INFORMATION                |139 |
# |**MONTGOMERY VILLAGE** |DRIVING UNDER THE INFLUENCE    |295 |
# |                   |CDS-POSS MARIJUANA/HASHISH     |267 |
# |                   |MENTAL TRANSPORT               |189 |
# |**OTHER**              |BURG FORCE-RES/NIGHT           |1   |
# |                   |CDS-MANU-HALLUC/LSD/PCP/ETC    |1   |
# |                   |CDS-POSS COCAINE & DERIVATIVES |1   |
# |**ROCKVILLE**          |POL INFORMATION                |270 |
# |                   |DRIVING UNDER THE INFLUENCE    |243 |
# |                   |LOST PROPERTY                  |157 |
# |**SILVER SPRING**      |CDS-POSS MARIJUANA/HASHISH     |382 |
# |                   |DRIVING UNDER THE INFLUENCE    |347 |
# |                   |POL INFORMATION                |258 |
# |**TAKOMA PARK**        |CDS-POSS MARIJUANA/HASHISH     |4   |
# |                   |CDS-SELL-MARIJUANA/HASHISH     |2   |
# |                   |DISORDERLY CONDUCT             |2   |
# |**WHEATON**            |DRIVING UNDER THE INFLUENCE    |308 |
# |                   |CDS-POSS MARIJUANA/HASHISH     |223 |
# |                   |POL INFORMATION                |200 |
#
#
# These results confirm that **Silver Spring** is the area where the most crimes occur. And this area correspond to the cities **Burtonsville, Takoma Park, Spencerville, Chevy Chase and Laurel**
#
#
# Other interesting analysis that can be taken is about the crimes per capita in each area. Considering the six districts of Montgomery County and the [2015 Annual Report on Crime](https://www.montgomerycountymd.gov/POL/Resources/Files/crime/MCP2015AnnualCrimeReportFINAL.pdf) developed by the Montgomery County Department of Police, the population of each district is:
#
# >```python
# population = {'ROCKVILLE': 149118,'BETHESDA': 182883,'SILVER SPRING': 152991,'WHEATON': 208283,'GERMANTOWN': 131391,'MONTGOMERY VILLAGE': 147486}
# ```
#
# >```python
# {'BETHESDA': 182883,
#  'GERMANTOWN': 131391,
#  'MONTGOMERY VILLAGE': 147486,
#  'ROCKVILLE': 149118,
#  'SILVER SPRING': 152991,
#  'WHEATON': 208283}
#  ```
#
# This information combined with the number of crimes committed in each district can be used to calculate the crimes per capita. In other words, if the number of crimes in a specific district is divided by the population correspondent to it, it will result in the value of crimes per capita. The code below executes this analysis.
#
#
# >```python
# p = pd.Series(population)
# c = crimes['Police District Name'].value_counts()
# crimes_per_capita = c.div(p)
# crimes_per_capita
# ```
# >```python
# BETHESDA              0.018498
# GERMANTOWN            0.020968
# MONTGOMERY VILLAGE    0.025847
# OTHER                      NaN
# ROCKVILLE             0.023337
# SILVER SPRING         0.036166
# TAKOMA PARK                NaN
# WHEATON               0.021005
# ```
#
# From this result, it is possible to conclude that **Silver Spring** is the district more violent. The following graph presents a comparison between all districts.
#
#
# >```python
# crimes_per_capita.plot(kind='barh', color='orangered')
# plt.title('Crimes Per Capita')
# plt.show()
# ```
#
# <img width="500" src="Crimes per capita.png">

# %% [markdown]
# ## 5. Analyzing types of crime
#
# The **Class Description** column tells something about the type of crime that was committed. It can be used to discover which crimes are committed most often.
#
# The following code shows the first five crimes most common
#
# >```python
# crimes.groupby(['Class Description', 'Class']).size().sort_values(ascending=False).to_frame('qtd').iloc[0:5]
# ```
#
# |**Class Description**          |**Class**|**qtd**|
# |-------------------------------------------------|
# |DRIVING UNDER THE INFLUENCE    |	2812  |	1710  |
# |CDS-POSS MARIJUANA/HASHISH     |	1834  |	1334  |
# |POL INFORMATION                |	2938  |	1191  |
# |LARCENY FROM AUTO OVER 200     |	614   |	914   |
# |LARCENY FROM BUILDING OVER 200 |	617   | 895   |
#
#
# And the least common are:
#
# >```python
# crimes.groupby(['Class Description', 'Class']).size().sort_values(ascending=True).to_frame('qtd').iloc[0:5]
# ```
#
# |**Class Description**          |**Class**|**qtd**|
# |-------------------------------------------------|
# |ABANDONED AUTO                 |	2811  |	1     |
# |ROB KNIFE/CUT - CONV. STORE    |	324   |	1     |
# |ANIMAL OFFENSE - HOT CAR       |	3213  |	1     |
# |PARKING OFFENSES               |	2814  |	1     |
# |LARCENY COIN MACH 50-199       |	628   | 1     |
#
# <br><br>
# In order to classify the crimes into **"Violent"** and **"Nonviolent"** the columns **Class Description** and **Class** were analyzed to find patterns that could help to assign the value *False* or *True* for each type of crime. It was verified that some words were common for violent crimes. Thus, it was assumed that for each **Class Description** that contained at least one of these words, it would receive value *True*.
# The dictionary with these words was created and a new column named **Violent** was associated to the dataset. This column contains *True* and *False* values.
#
# >```python
# Violent_True = ['AGG ASSLT', 'ABUSE', 'ASSAULT', 'BURG FORCE', 'BOMB', 'EXPLOSIVE', 'HOMICIDE','FIRE OTHER', 'KIDNAPPING', 'RAPE', 'ROB ', 'SEX OFFENDER', 'WEAPON']
# crimes['Violent'] = crimes['Class Description'].str.contains('|'.join(Violent_True), case=False)
# ```
#
# After the definition of the dictionary, it was analyzed how many *False* and *True* values the new list **Violent** contains.
#
# >```python
# x=(crimes['Violent'] == True).value_counts()
# # This funtions counts how many False and True there are in Violent
# print(x)
# ```
# >```python
# Output:
# False    20118
# True      3251
# ```
#
# And to visualize part of the final result, we can apply the function groupby in order to see the values correlated.
#
# >```python
# crimes.groupby(['Class', 'Class Description', 'Violent']).size().sort_values(ascending=False).iloc[0:30]
# ```
# | **Class**| **Class Description**          |**Violent** |**qtd**|
# |--------------------------------------------------------------|
# | 2812 |  DRIVING UNDER THE INFLUENCE       |False       |1710 |
# | 1834 |  CDS-POSS MARIJUANA/HASHISH        |False       |1334 |
# | 2938 |  POL INFORMATION                   |False       |1191 |
# | 614  |  LARCENY FROM AUTO OVER 200        |False       |914  |
# | 617  |  LARCENY FROM BUILDING OVER  200   |False       |895  |
# | 2942 |  MENTAL TRANSPORT                  |False       |841  |
# | 1412 |  VANDALISM-MOTOR VEHICLE           |False       |762  |
# | 2941 |  LOST PROPERTY                     |False       |729  |
# | 619  |  LARCENY OTHER OVER  200           |False       |652  |
# | 634  |  LARCENY FROM AUTO UNDER  50       |False       |610  |
# | 1013 |  FORGERY/CNTRFT - IDENTITY THEFT   |False       |596  |
# | 613  |  LARCENY SHOPLIFTING OVER  200     |False       |529  |
# | 623  |  LARCENY SHOPLIFTING  50 -  199    |False       |489  |
# | 2216 |  LIQUOR - DRINK IN PUB OVER 21     |False       |482  |
# | 2413 |  DISORDERLY CONDUCT                |False       |464  |
# | 811  |  ASSAULT & BATTERY - CITIZEN       |True        |382  |
# | 624  |  LARCENY FROM AUTO  50 -  199      |False       |356  |
# | 1011 |  FORGERY/CNTRFT-CRDT CARDS         |False       |342  |
# | 2943 |  MISSING PERSON                    |False       |341  |
# | 821  |  SIMPLE ASSAULT - CITIZEN          |True        |311  |
# | 1864 |  CDS IMPLMNT-MARIJUANA/HASHISH     |False       |297  |
# | 711  |  AUTO THEFT - PASSENGER VEHICLE    |False       |293  |
# | 813  |  ASSAULT & BATTERY SPOUSE/PARTNER  |True        |290  |
# | 635  |  LARCENY AUTO PART UNDER  50       |False       |267  |
# | 2111 |  JUVENILE RUNAWAY                  |False       |258  |
# | 633  |  LARCENY SHOPLIFTING UNDER  50     |False       |258  |
# | 512  |  BURG FORCE-RES/DAY                |True        |240  |
# | 2737 |  TRESPASSING                       |False       |223  |
# | 2913 |  SUDDEN DEATH NATURAL              |False       |223  |
# | 627  |  LARCENY FROM BUILDING  50-199     |False       |221  |
#
#
# The table showed that the most common *"Nonviolent"* crime is **DRIVING UNDER THE INFLUENCE (Class 2812)**, that occured 1710 times in the data. And the most common *"Violent"* is **ASSAULT & BATTERY - CITIZEN (Class 811)**, presented 382 times.
#
# The visual analysis of these results is presented in the pie chart below:
#
# >```python
# x=(crimes['Violent'] == True).value_counts()
# x.plot(kind='pie', explode=(0.1,0), autopct='%1.1f%%', shadow=True, startangle=90)
# plt.title('Violent Crimes')
# plt.show()
# ```
#
# <img width="400" img src="Violent Crimes.png">
# <br>
# From the pie chart is clear that the most common crimes described in the database are **nonviolent**, and they correspond to **86,1%** from all incidents.

# %% [markdown]
# ## 6. Combine Analysis
#
# In addition to all analysis already made, the information provided by each column can also be combined to answer complex questions, for example where an when are the most violent (and nonviolent) crimes committed.
#
# If the first interest is to analyze the question *where*, the columns **Zip Code**, **City** and **Violent** can be associated.
#
# >```python
# crimes.groupby(['Zip Code', 'City', 'Violent']).size().sort_values(ascending=False).iloc[0:30]
# ```
#
# | Zip Code|  City           |     Violent          |
# |------------------------------------------------|
# | 20910.0  | SILVER SPRING       |False  |    1748 |
# | 20904.0  | SILVER SPRING       |False   |   1481 |
# | 20902.0  | SILVER SPRING       |False    |  1413 |
# | 20874.0  | GERMANTOWN          |False    |  1220 |
# | 20877.0  | GAITHERSBURG        |False    |  1212 |
# | 20850.0  | ROCKVILLE           |False    |  1190 |
# | 20906.0  | SILVER SPRING       |False    |  1109 |
# | 20852.0  | ROCKVILLE           |False    |  1087 |
# | 20878.0  | GAITHERSBURG        |False    |  1072 |
# | 20901.0  | SILVER SPRING       |False    |   829 |
# | 20814.0  | BETHESDA            |False    |   816 |
# | 20876.0  | GERMANTOWN          |False    |   664 |
# | 20886.0  | MONTGOMERY VILLAGE  |False    |   576 |
# | 20817.0  | BETHESDA            |False    |   525 |
# | 20879.0  | GAITHERSBURG        |False    |   482 |
# | 20903.0  | SILVER SPRING       |False    |   478 |
# | 20854.0  | POTOMAC             |False    |   463 |
# | 20815.0  | CHEVY CHASE         |False    |   458 |
# | 20853.0  | ROCKVILLE           |False    |   352 |
# | 20851.0  | ROCKVILLE           |False    |   350 |
# | 20832.0  | OLNEY               |False    |   348 |
# | 20895.0  | KENSINGTON          |False    |   302 |
# | 20904.0  | SILVER SPRING       |True     |   298 |
# | 20910.0  | SILVER SPRING       |True     |   263 |
# | 20866.0  | BURTONSVILLE        |False    |   245 |
# | 20855.0  | DERWOOD             |False    |   239 |
# | 20902.0  | SILVER SPRING       |True     |   234 |
# | 20905.0  | SILVER SPRING       |False    |   232 |
# | 20877.0  | GAITHERSBURG        |True     |   228 |
# | 20906.0  | SILVER SPRING       |True     |   228 |
#
#
#
# This result presents,in an descending order, how many *Violent Crimes* are associa†ed with a specific Zip Code. In other words, it shows which Zip Code has the highest number of violent and nonviolent incidents.
#
# We can also associate column **Class Description** to have an idea about what type of crime was committed in a specific area.
#
# >```python
# crimes.groupby(['Zip Code', 'City','Class Description', 'Violent']).size().sort_values(ascending=False).iloc[0:30]
# ```
#
#
# | Zip Code  |City           |Class Description               |Violent|        |
# |---------------------------------------------------------------------------|
# | 20814.0   |BETHESDA       |DRIVING UNDER THE INFLUENCE      |False      | 141 |
# | 20878.0   |GAITHERSBURG   |POL INFORMATION                  |False      | 132 |
# | 20877.0   |GAITHERSBURG   |DRIVING UNDER THE INFLUENCE      |False      | 130 |
# | 20904.0   |SILVER SPRING  |CDS-POSS MARIJUANA/HASHISH       |False      | 127 |
# | 20910.0   |SILVER SPRING  |CDS-POSS MARIJUANA/HASHISH       |False      | 126 |
# | 20874.0   |GERMANTOWN     |CDS-POSS MARIJUANA/HASHISH       |False      | 117 |
# | 20850.0   |ROCKVILLE      |POL INFORMATION                  |False      | 115 |
# | 20902.0   |SILVER SPRING  |DRIVING UNDER THE INFLUENCE      |False      | 112 |
# | 20852.0   |ROCKVILLE      |DRIVING UNDER THE INFLUENCE      |False      | 111 |
# | 20904.0   |SILVER SPRING  |DRIVING UNDER THE INFLUENCE      |False      | 110 |
# | 20910.0   |SILVER SPRING  |POL INFORMATION                  |False      | 109 |
# | 20874.0   |GERMANTOWN     |DRIVING UNDER THE INFLUENCE      |False      | 105 |
# | 20901.0   |SILVER SPRING  |DRIVING UNDER THE INFLUENCE      |False      | 102 |
# | 20910.0   |SILVER SPRING  |LARCENY FROM AUTO OVER 200       |False      |  98 |
# | ||LIQUOR - DRINK IN PUB OVER 21|    False      |  95                          |
# | ||DISORDERLY CONDUCT            |   False     |   93                          |
# | 20876.0   |GERMANTOWN     |DRIVING UNDER THE INFLUENCE      |False       | 92 |
# | 20902.0   |SILVER SPRING  |DISORDERLY CONDUCT               |False       | 92 |
# | 20878.0   |GAITHERSBURG   |DRIVING UNDER THE INFLUENCE      |False       | 89 |
# | 20850.0   |ROCKVILLE      |LOST PROPERTY                    |False       | 87 |
# | 20878.0   |GAITHERSBURG   |CDS-POSS MARIJUANA/HASHISH       |False       | 87 |
# | 20902.0   |SILVER SPRING  |CDS-POSS MARIJUANA/HASHISH       |False       | 85 |
# | ||LARCENY SHOPLIFTING OVER 200|     False        |84                          |
# | 20910.0   |SILVER SPRING  |DRIVING UNDER THE INFLUENCE      |False      |  81 |
# | 20906.0   |SILVER SPRING  |DRIVING UNDER THE INFLUENCE      |False      |  81 |
# | 20904.0   |SILVER SPRING  |LARCENY FROM AUTO OVER 200       |False      |  80 |
# | 20877.0   |GAITHERSBURG   |CDS-POSS MARIJUANA/HASHISH       |False      |  76 |
# | 20910.0   |SILVER SPRING  |LARCENY FROM BUILDING OVER 200   |False      |  75 |
# | 20877.0   |GAITHERSBURG   |LARCENY SHOPLIFTING OVER 200     |False     |   73 |
# | 20850.0   |ROCKVILLE      |DRIVING UNDER THE INFLUENCE      |False    |    72 |
#
#
#
#
#
# The Zip Code **20814.0**, which corresponds to **Bethesda** City, experienced **141 times** the incident **Driving under the influence**. Therefore, it was the Zip Code with the more repeatedly incident.
#
# <br>
# <br>
#
# The questions related to *when* can be answered by the column **Start Date / Time** combined with the column **Violent**.
#
# >```python
# crimes["Start Date"]= pd.to_datetime(crimes["Start Date / Time"]).dt.weekday_name
# crimes_weekday = crimes.groupby(["Start Date", "Violent"]).size().sort_values(ascending=False)
# crimes_weekday
# ```
#
# >```python
# Friday      False      3234
# Tuesday     False      2966
# Wednesday   False      2958
# Thursday    False      2892
# Saturday    False      2876
# Monday      False      2711
# Sunday      False      2481
# Tuesday     True        497
# Friday      True        485
# Wednesday   True        472
# Saturday    True        467
# Thursday    True        457
# Monday      True        446
# Sunday      True        427
# ```
#
# **Friday** is the weekday with more *nonviolent* crimes (3234 times) and **Tuesday** is the weekday with more *violent* incidents (497).
#
# And to analyze in witch month nonviolent and violent crimes are mostly like to occur:
#
# >```python
# crimes["Start Date"]= pd.to_datetime(crimes["Start Date / Time"]).dt.month
# crimes_month = crimes.groupby(["Start Date", "Violent"]).size().sort_values(ascending=False)
# crimes_month
# ```
#
# >```python
# 8           False      3433
# 10          False      3425
# 9           False      3332
# 11          False      3262
# 12          False      3070
# 7           False      2999
# 11          True        584
# 10          True        568
# 9           True        551
# 8           True        538
# 12          True        490
# 7           True        451
# 6           False       290
# 5           False        98
# 1           False        64
# 4           False        61
# 3           False        54
# 1           True         31
# 2           False        30
# 6           True         17
# 5           True         10
# 4           True          5
# 2           True          4
# 3           True          2
# ```
#
# **August**, following by **October**, are the months that more nonviolent crimes occurred. And **November** and **October** are the ones with more registration of violent crimes.
#
#
# These results can also be analyzed by the following graph
#
# >```python
# crimes[crimes.Violent == True]['City'].value_counts().plot(kind='bar', color='orangered')
# plt.title('Crimes per City')
# plt.show()
# ```
#
# <img width="400" img src="Crimes per City.png">

# %% [markdown]
# ## 7. Posing and answering questions
#
# Besides the analyses that were taken, there are more interesting interpretations that can be taken using the information provided by the dataset.
#
# ### 7.1 Violent and Nonviolent Crimes per Police District
#
# The rate crimes per district was an analysis made previously. However, it is possible to combine the information provided by the dictionary *Violent* which defines the crimes into violent and nonviolent. This combination allows interpreting which violent and nonviolent crime occur in each district. This information can be used to point what district has more problems with a specific incident.
#
#
# >```python
# aux = crimes.groupby(['Police District Name', 'Violent'] ).size().groupby(level=[0,1]).sum()
# aux
# ```
#
# >```python
# BETHESDA              False      3039
#                       True        344
# GERMANTOWN            False      2381
#                       True        374
# MONTGOMERY VILLAGE    False      3259
#                       True        553
# OTHER                 False         7
#                       True          1
# ROCKVILLE             False      3016
#                       True        464
# SILVER SPRING         False      4685
#                       True        848
# TAKOMA PARK           False        22
#                       True          1
# WHEATON               False      3709
#                       True        666
# ```
#
# This results show that **Silver Spring** was the Police District with more violent crimes incident. And disconsidering **Takoma Park** and **OTHER**, **Bethesda** was the distric with less violent incidents. In general, all districts presented more nonviolent crimes than violent.
#
#
# >```python
# aux.plot(kind='bar', color='orangered')
# plt.xticks(rotation = 90)
# plt.title('Crimes per Police District')
# plt.show()
# ```
#
# <img width="400" img src="Crimes per Police District.png">
#
#
# ### 7.2  Crimes per Place
#
# Another interesting column that can be used to get information regarding crimes is the column **Place**. As described in the preview sections, this column indicate in which place the incident occurred. This information is useful to comprehend the nature of the crime. The following code return common places where the majority of crimes occurred and if they were violent or nonviolent crime.
#
#
# >```python
# crimes_place = crimes.groupby(["Place", "Violent"]).size().groupby(level=[0,1]).sum().sort_values(ascending=False).iloc[0:15]
# crimes_place
# ```
#
# | Place |                              Violent   |   Count   |
# |------------------------------------------------------|
# |Street - In vehicle                 |False    |  2483|
# |Residence - Single Family           |False    |  1966|
# |Street - Residential                |False    |  1507|
# |Other/Unknown                       |False    | 1371|
# |Residence - Apartment/Condo         |False    |  1311|
# |Parking Lot - Residential           |False    |   991|
# |Parking Lot - Commercial            |False    |   912|
# |Residence - Driveway                |False    |   788|
# |Residence - Single Family           |True     |   763|
# |Residence -Townhouse/Duplex         |False    |   705|
# |Street - Commercial                 |False    |   633|
# |Retail - Department/Discount Store  |False    |   602|
# |Street - Other                      |False    |   542|
# |Residence - Apartment/Condo         |True     |  536|
# |School/College                      |False    |  460|
#
#
# The result is quite interesting. The most common place is **Street - In vehicle** and if this result is compared to the one reached in section 5, where it was affirmed that the most common nonviolent crime is **DRIVING UNDER THE INFLUENCE**, it will be possible to find a correlation between them. Thus, it is possible to ensure that these analyses are true and they are complementaries.
#
#
# ### 7.3 Police District efficiency
#
# The column **Start date/time** provides information regarding the date and time an incident occurred. In contrast, the column **Dispatch Date / Time** indicates when an Officer was designated to verify an incident. A comparison between the results presented in these columns allows having an idea about the Police District efficiency. In other words, if the difference of time between these columns was insignificant, it means that the incident was answered in a short time. However, if this difference is considerable, it could mean that the Police Department does not have enough resources or there is something interrupting the work development.
#
#
# >```python
# crimes['Minute'] = pd.to_datetime(crimes['Dispatch Date / Time']) - pd.to_datetime(crimes['Start Date / Time'])
# c = crimes.pivot_table(index=['Police District Name','Minute'], values="Incident ID", aggfunc='count')
# c.reset_index().sort_values(['Police District Name','Incident ID'],ascending=[True, False]).groupby(['Police District Name']).head(3).set_index(['Police District Name','Minute'])
# ```
#
# |**Police District Name**|	**Minute**|**Incident ID**|
# |--------------------|--------|------------|
# |BETHESDA	         |00:00:04|	30|
# |                    |00:00:22|	29|
# |                    |00:00:09|	28|
# |GERMANTOWN	         |00:00:48|	36|
# |                    |00:00:36|32|
# |                    |00:00:49|	32|
# |MONTGOMERY VILLAGE	 |00:00:56|	41|
# |                    |00:00:13|	39|
# |                    |00:00:51|	39|
# |OTHER	             |00:00:20|	1|
# |                    |00:00:41|	1|
# |                    |00:00:54|	1|
# |ROCKVILLE	         |00:00:05|	34|
# |                    |00:00:56|	31|
# |                    |00:00:02| 30|
# |SILVER SPRING	     |00:00:43|	66|
# |                    |00:00:29|	64|
# |                    |00:00:18|	60|
# |TAKOMA PARK         |-1 days +16:45:12|	1|
# |                    |00:00:07|1|
# |                    |00:00:08|	1|
# |WHEATON	         |00:00:16|54|
# |                    |00:00:14|49|
# |                    |00:00:37|47|
#
#
#
# The analysis showed that the difference of time is not expressive. The majority of the data differ just in seconds. Nevertheless, either in seconds it is possible to get interesting information. For example, it is possible to analyze which district spends less time to answers a call.
# Bethesda and Rockville have a close number of incidents. So, they are a good example to get an analysis regarding the time to answer a call. The last table presented the first values of time for each district according to the number of Incidents ID. This table showed that in a general analysis Bethesda tends to be faster than Rockville.
